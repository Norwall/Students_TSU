# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec

data = pd.read_csv('train titanic.csv', sep = ',')
df4 = data.copy(deep = True)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#data.head()

# %%
#data.tail()

# %%
ds = data['Survived'].value_counts().reset_index()

# plt.figure(figsize=(10, 7))

# plt.pie(ds['Survived'], autopct='%1.1f%%', explode = [0.1,0], colors = ['purple', 'blue'])

# plt.title('А сколько осталось?')
# plt.legend(["Умершие", 'Выжившие'])

# plt.show()
ds
# Out:
#    index  Survived
# 0      0       549
# 1      1       342

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 7))

ax[0].pie(ds['Survived'], autopct='%1.1f%%', explode = [0.1,0], colors = ['purple', 'yellow'])
ax[0].set_title('А сколько осталось?')
ax[0].legend(["Умершие", 'Выжившие'], loc = [0.75,0.85])



x = ['нет', 'да']
ax[1].bar(ds['index'],ds['Survived'],color = ['green', 'orange'])
ax[1].set_title('А сколько осталось?')
ax[1].set_ylabel('Выжившие')
ax[1].set_xlabel('Выжили?')
ax[1].set_xticks(ds['index'])
ax[1].set_xticklabels([i for i in x])
colors = {'Умершие': 'green', 'Выжившие':'orange'}
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
ax[1].legend(handles, labels)

# %%
# dsex = data.groupby('Sex')['Survived'].sum().reset_index()
# #dsexW =  data.groupby(['Sex','Survived'])['Survived'].agg(count='count').reset_index()
data1 = data[data['Sex'].isin(['male'])] 
data2 = data[data['Sex'].isin(['female'])] 
# dsexM = data1.groupby(['Sex','Survived'])['Survived'].agg(count='count').reset_index()
# dsexF = data2.groupby(['Sex','Survived'])['Survived'].agg(count='count').reset_index()



# fig, ax = plt.subplots(1, 2, figsize=(10, 7))


# x = ['Девушки', 'Джентельмены']
# ax[0].bar(dsex['Sex'],ds['Survived'],color = ['magenta', 'black'])
# ax[0].set_title('Выжившие vs пол')
# ax[0].set_ylabel('Выжившие')
# ax[0].set_xlabel('Пол')
# ax[0].set_xticks(dsex['Sex'])
# ax[0].set_xticklabels([i for i in x])
# colors = {'Девушки': 'magenta', 'Джентельмены':'black'}
# labels = list(colors.keys())
# handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
# ax[0].legend(handles, labels)




# n_ticks = np.arange(len(dsexF['Sex']))
# offset = 0.2
# w = 0.4
# ax[1].bar(n_ticks - offset, dsexM['count'], width=w)
# ax[1].bar(n_ticks + offset, dsexF['count'], width=w)
# ax[1].set_title('Выжившие vs пол')
# ax[1].set_ylabel('Выжившие')
# ax[1].set_xlabel('Пол')
#ax[1].set_xticks(dsexF['Survived'])
#ax[1].set_xticklabels([i for i in x])
# colors = {'Девушки': 'magenta', 'Джентельмены':'black'}
# labels = list(colors.keys())
# handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
# ax[1].legend(handles, labels)

# %%
# data1 = data[data['Sex'].isin(['male'])] 
# data2 = data[data['Sex'].isin(['female'])] 
# #dsexM = data1['Survived'].value_counts()
# #dsexF = data2['Survived'].value_counts()
# dsexG = data1.groupby(['Sex','Survived'])['Survived'].agg(count='count').reset_index()
# dsexW = data2.groupby(['Sex','Survived'])['Survived'].agg(count='count').reset_index()
# print(dsexG)
# print(dsexW)

# %%
# fig, ax = plt.subplots(1, 2,  figsize=(10, 7))

# plt.subplot(121)
# sns.barplot(data = data, x = "Sex",y = "Survived", hue = "Sex")

# plt.subplot(122)
# sns.catplot(data = data, x = "Sex", hue = "Survived", kind = 'count')

# %%
f, ax = plt.subplots(1,2, figsize = (12,5))
data[['Sex','Survived']].groupby(['Sex']).sum().plot.bar(ax=ax[0])
ax[0].set_title('Выживание vs пол')
sns.countplot(x='Sex', hue = 'Survived', data=data, ax=ax[1])
ax[1].set_title('Пол: Выживание vs пол')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
f, ax = plt.subplots(1,3, figsize = (12,5))

sns.countplot(x='Sex', hue = 'Pclass', data=data, ax=ax[0])
ax[0].set_title('Классы')
sns.countplot(x='Pclass', hue = 'Survived', data=data, ax=ax[1])
sns.countplot(x='Pclass', data=data, ax=ax[2])
sns.displot(data,x="Sex", aspect = 0.95, bins=20, hue ='Pclass', col ='Survived', kind='hist', multiple = 'dodge')

# %%
sns.violinplot(data = data, x = 'Pclass', y = 'Age', hue = 'Survived', split = True)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,7))

sns.violinplot(data = data1, x = 'Pclass', y = 'Age', hue = 'Survived', split = True, ax=ax[0])
ax[0].set_title('Мужчин')
sns.violinplot(data = data2, x = 'Pclass', y = 'Age', hue = 'Survived', split = True, ax=ax[1])
ax[1].set_title('Женщины')
# Out:
# Text(0.5, 1.0, 'Женщины')

# %%
sns.violinplot(data = data, x = 'Sex', y = 'Age', hue = 'Survived', split = True)

# %%
# fig, ax = plt.subplots(1,2, figsize=(50,35))
# data3 = data[data['Survived'].isin([1])] 
# data4 = data[data['Survived'].isin([0])] 

# sns.countplot(x='Age', hue = 'Survived', data=data3, ax=ax[0], palette = 'BuGn')
# ax[0].set_title('Выжили')
# sns.countplot(x='Age', hue = 'Survived', data=data4, ax=ax[1], palette = 'OrRd')
# ax[1].set_title('Не выжили')

# %%
dSu = data[data['Survived'] == 1]
dSu1 = data[data['Survived'] == 0]
# f, ax = plt.subplots(1,3, figsize = (15,8))


# dSu.groupby('Survived')['Age'].plot(kind='hist', bins = 50, color = 'green', ec = 'black', ax=ax[0], xlim = (0,80), ylim = (0,40))
# ax[0].set_title('Survived')

# dSu1.groupby('Survived')['Age'].plot(kind='hist', bins = 50, color = 'red', ec = 'black', ax=ax[1], xlim = (0,80), ylim = (0,40))
# ax[1].set_title('Not survived')

# data.groupby('Age').plot(kind='hist', bins = 50, ec = 'black', ax=ax[2], xlim = (0,80), ylim = (0,40))
# ax[2].set_title('???')

# %%
fig = plt.figure(figsize=(30, 21))
gs = GridSpec(nrows=3, ncols=4)

fig.add_subplot(gs[0,:2])
s1 = sns.histplot(data = dSu, x = 'Age', hue = 'Survived', bins = 50, palette = 'Greens')
s1.set_title('Survived')
s1.set(ylim=(0, 35))
s1.set(xlim=(0, 80))

fig.add_subplot(gs[0,2:4])
s2 = sns.histplot(data = dSu1, x = 'Age', hue = 'Survived', bins = 50, palette = 'OrRd')
s2.set_title('Not survived')
s2.set(xlim=(0, 80))
s2.set(ylim=(0, 35))



fig.add_subplot(gs[1,:])
a3 = sns.histplot(data = data, x = 'Age', bins = 50)
a3.set_title('Ages')
a3.set(xlim=(0, 80))
a3.set(ylim=(0, 60))


fig.add_subplot(gs[2,0])
sns.countplot(x='Pclass', data=data,)

fig.add_subplot(gs[2,1])
sns.violinplot(data = data2, x = 'Pclass', y = 'Age', hue = 'Survived', split = True)

fig.add_subplot(gs[2,2])
sns.countplot(x='Sex', hue = 'Survived', data=data)

fig.add_subplot(gs[2,3])
sns.violinplot(data = data, x = 'Sex', y = 'Age', hue = 'Survived', split = True)

# %%
data['Age_band'] = np.random.randint(1, size=(891,1))

data.loc[((data.Age<=16),'Age_band')] = 1
data.loc[((data.Age>16)&(data.Age<=32), 'Age_band')] = 2
data.loc[((data.Age>32)&(data.Age<=48), 'Age_band')] = 3
data.loc[((data.Age>48)&(data.Age<=64), 'Age_band')] = 4
data.loc[((data.Age>64), 'Age_band')] = 5
df = data.copy(deep = True)

# %%
data.loc[((data.Age_band == 0),'Age')] = data['Age'].median()
data.loc[((data.Age<=16),'Age_band')] = 1
data.loc[((data.Age>16)&(data.Age<=32), 'Age_band')] = 2
data.loc[((data.Age>32)&(data.Age<=48), 'Age_band')] = 3
data.loc[((data.Age>48)&(data.Age<=64), 'Age_band')] = 4
data.loc[((data.Age>64), 'Age_band')] = 5
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.factorplot(data = df,x ='Age_band', y ='Survived')

sns.factorplot(data = data,x ='Age_band', y ='Survived')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(data = df,x ='Age_band', y ='Survived', hue = 'Pclass')

sns.factorplot(data = data,x ='Age_band', y ='Survived', hue = 'Pclass')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#SibSp	Parch
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Social'] = 0
data.loc[((df4.Parch > 0) | (data.SibSp > 0 ),'Social')] = 'Not alone'
data.loc[((df4.Parch == 0) & (data.SibSp == 0 ),'Social')] = 'Alone'
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1 = data[data['Social'].isin(['Alone'])] 
data2 = data[data['Social'].isin(['Not alone'])] 

fig = plt.figure(figsize=(15, 7))
gs = GridSpec(nrows=3, ncols=2)

fig.add_subplot(gs[0,0])
s1 = sns.countplot(data = data, x = 'Sex', hue = 'Social')


fig.add_subplot(gs[0,1])
s2 = sns.countplot(data = data, x = 'Pclass', hue = 'Social')

fig.add_subplot(gs[1,0])
s3 = sns.countplot(data = data, x = 'Survived', hue = 'Social')

fig.add_subplot(gs[1,1])
s4 = sns.countplot(data = data, x = 'Social', hue = 'Age_band')

fig.add_subplot(gs[2,0])
s5 = sns.histplot(data = data1, x = 'Age', hue = 'Social', palette = 'Greens', kde = True)

fig.add_subplot(gs[2,1])
s6 = sns.histplot(data = data2, x = 'Age', hue = 'Social', palette = 'OrRd', kde = True)


s6 = sns.displot(data = data, x = 'Age', hue = 'Survived',col ='Social', palette = 'OrRd', kde = True, aspect = 1.168)

# %%
s6 = sns.displot(data = data, x = 'Age', hue = 'Survived',col ='Social', palette = 'OrRd', kde = True)
